# %%
msg = "Hello world"
print(msg)
# Out:
# Hello world

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as piechart

# Add Subgroups, Number of Students Enrolled, Percent of Enrollees
subgroups = ['African American', 'Asian', 'Hispanic', 'Native American', 'Pacific Islander', 'White', 'Multiple Races']
num_enrolled = [2769, 636, 26841, 2514, 447, 23035, 2022]
perc_enrolled = np.array([4.75, 1.09, 46.07, 4.32, 0.77, 39.54, 3.47])

# Create a data frame for the groups
studentPop = pd.DataFrame({'Race' : subgroups,
                           'Population': num_enrolled,
                           'Percentage': perc_enrolled})
# Print out table
print(studentPop)

# Create the Pie chart and legend
piechart.pie(perc_enrolled, labels= subgroups)
piechart.legend()
# Show chart
piechart.show()
# Out:
#                Race  Population  Percentage
# 0  African American        2769        4.75
# 1             Asian         636        1.09
# 2          Hispanic       26841       46.07
# 3   Native American        2514        4.32
# 4  Pacific Islander         447        0.77
# 5             White       23035       39.54
# 6    Multiple Races        2022        3.47
